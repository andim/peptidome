# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
from matplotlib import colors
import matplotlib.ticker as ticker
from scipy.stats import sem
from collections import Counter as _Counter

import sys
sys.path.append('..')
sys.path.append('../../../code')
from lib import *
plt.style.use('../../../code/peptidome.mplstyle')
from lib.plotting import model_labels as labels

datadir = '../../../code/mivsdist/data'
figdatadir = './'
import json

# %%
import matplotlib.ticker as ticker

# %%
fig, ax = plt.subplots()

label_map = {
    'Human': 'Human Proteome',
    'Malaria': 'P. Falciparum Proteome',
    'Viruses': 'Human Virus Proteomes'
}
for species in ['Human', 'Malaria','Viruses']:
    df = pd.read_csv(f'{datadir}/mutualinformation-%s.csv'%species)
#     err = ax.errorbar(df['gaps']+1, df['mutualinformation'],
#             2*df['mutualinformation_std'], fmt='_', label=species, ms=3)
    ax.plot(df['gaps']+1, df['mutualinformation'], 'o',label=label_map[species],ms=2)

#    ax.plot(df['gaps']+1, df['shuffledmutualinformation'], '_', ms=3,
#            label=('shuffled') if species == 'Human' else '', c=err.lines[0].get_color())
d = np.linspace(1, 200)
#ax.plot(d, 0.005*np.exp(-d/50), zorder=10, label='exponential ($d_c=50$)')
l, = ax.plot(d, 0.02*d**-.5, zorder=10, c='k', label=r'$d^{-1/2}$')
ax.legend(loc='upper right', ncol=1)
ax.set_ylim(0.0004, 0.05)
ax.set_xlim(0.95, 251.0)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Distance')
ax.set_ylabel('Mutual Information (bits)')
fig.tight_layout()
plt.savefig('../mutual_information.png')
plt.savefig('../mutual_information.svg')

# %%
df['mutualinformation'].max()
# Out:
# np.float64(0.0097886844245164)

# %%
def get_counter(kmers):
    sb = ""
    for k in kmers:
        for i in range(kmers[k]):
            sb += k
    c =  _Counter(sb)
    denominator = len(sb)

    return [c[letter]/denominator for letter in aminoacids]

# %%
freqs = {}


fasta_dir = '../../../data/'
for fasta in [
        'human-viruses-uniref90-filtered.fasta',
        'UP000000589Mouse.fasta.gz',
        'UP000001450Malaria.fasta.gz',
        'UP000000437Zebrafish.fasta.gz',
        'UP000000750StrepA.fasta',
        'UP000001584Tuberculosis.fasta',
        'UP000000539Chicken.fasta.gz',
        'UP000000817Listeria.fasta',
        'UP000005640Human.fasta.gz'
    ]:
    print(fasta)
    kmers = count_kmers_proteome(os.path.join(fasta_dir, fasta),9)
    freqs[fasta]  = get_counter(kmers)
    print('-----------------------------------')
# Out:
# human-viruses-uniref90-filtered.fasta
# -----------------------------------
# UP000000589Mouse.fasta.gz
# -----------------------------------
# UP000001450Malaria.fasta.gz
# -----------------------------------
# UP000000437Zebrafish.fasta.gz
# -----------------------------------
# UP000000750StrepA.fasta
# -----------------------------------
# UP000001584Tuberculosis.fasta
# -----------------------------------
# UP000000539Chicken.fasta.gz
# -----------------------------------
# UP000000817Listeria.fasta
# -----------------------------------
# UP000005640Human.fasta.gz
# -----------------------------------

# %%
aminoacids
# Out:
# 'ACDEFGHIKLMNPQRSTVWY'

# %%
load_proteomes()
# Out:
#                                         fullname  \
# shortname
# Human                               Homo sapiens
# Mouse                               Mus Musculus
# Chicken                            Gallus gallus
# Zebrafish                            Danio rerio
# Yeast                   Saccharomyces cerevisiae
# Cockroach                    Blattella germanica
# Wheat                          Triticum aestivum
# Soybean                              Glycine max
# Vaccinia                          Vaccinia virus
# InfluenzaB                           Influenza B
# InfluenzaA                           Influenza A
# CMV                              Cytomegalovirus
# HCV                                Hepacivirus C
# HBV                            Hepatitis B virus
# HSV1                      Herpex simplex virus 1
# DENV                                Dengue virus
# HIV                 Human immunodeficiency virus
# EBV                           Epstein-Barr virus
# Ebola                                 Ebolavirus
# Ecoli                           Escherichia coli
# Tuberculosis          Mycobacterium tuberculosis
# Listeria                  Listeria monocytogenes
# Burkholderia           Burkholderia pseudomallei
# Meningococcus             Neisseria meningitidis
# StrepA                    Streptococcus pyogenes
# Hpylori                      Helicobacter pylori
# Lyme                     Borreliella burgdorferi
# Tetanus                       Clostridium tetani
# Leprosy                     Mycobacterium leprae
# Malaria                    Plasmodium falciparum
# Chagas                         Trypanosoma cruzi
# OnchocercaVolvulus           Onchocerca volvulus
#
#                                         iedbname speciesid   proteomeid  \
# shortname
# Human                               Homo sapiens      9606  UP000005640
# Mouse                               Mus Musculus     10090  UP000000589
# Chicken                            Gallus gallus      9031  UP000000539
# Zebrafish                           Danrio rerio      7955  UP000000437
# Yeast                                                       UP000002311
# Cockroach                    Blattella germanica      6973  UP000245037
# Wheat                          Triticum aestivum      4565  UP000019116
# Soybean                              Glycine max      3847  UP000008827
# Vaccinia                          Vaccinia virus            UP000000344
# InfluenzaB                           Influenza B            UP000127412
# InfluenzaA                     Influenza A virus            UP000116233
# CMV                      Human betaherpesvirus 5            UP000008991
# HCV                                Hepacivirus C            UP000000518
# HBV                            Hepatitis B virus            UP000008591
# HSV1                    Human alphaherpesvirus 1            UP000106517
# DENV                                Dengue virus            UP000002500
# HIV                 Human immunodeficiency virus            UP000002241
# EBV                     Human gammaherpesvirus 4            UP000153037
# Ebola                                 Ebolavirus            UP000007209
# Ecoli                           Escherichia coli            UP000000558
# Tuberculosis          Mycobacterium tuberculosis            UP000001584
# Listeria                  Listeria monocytogenes            UP000000817
# Burkholderia           Burkholderia pseudomallei            UP000000605
# Meningococcus             Neisseria meningitidis            UP000000425
# StrepA                    Streptococcus pyogenes            UP000000750
# Hpylori                      Helicobacter pylori            UP000000429
# Lyme                     Borreliella burgdorferi            UP000001807
# Tetanus                       Clostridium tetani            UP000001412
# Leprosy                     Mycobacterium leprae            UP000000806
# Malaria                    Plasmodium falciparum     36329  UP000001450
# Chagas                         Trypanosoma cruzi    353153  UP000002296
# OnchocercaVolvulus           Onchocerca volvulus      6282  UP000024404
#
#                             type  \
# shortname
# Human                 vertebrate
# Mouse                 vertebrate
# Chicken               vertebrate
# Zebrafish             vertebrate
# Yeast                     fungus
# Cockroach           invertebrate
# Wheat                      plant
# Soybean                    plant
# Vaccinia                   virus
# InfluenzaB                 virus
# InfluenzaA                 virus
# CMV                        virus
# HCV                        virus
# HBV                        virus
# HSV1                       virus
# DENV                       virus
# HIV                        virus
# EBV                        virus
# Ebola                      virus
# Ecoli                  bacterium
# Tuberculosis           bacterium
# Listeria               bacterium
# Burkholderia           bacterium
# Meningococcus          bacterium
# StrepA                 bacterium
# Hpylori                bacterium
# Lyme                   bacterium
# Tetanus                bacterium
# Leprosy                bacterium
# Malaria                 parasite
# Chagas                  parasite
# OnchocercaVolvulus      parasite
#
#                                                               comment  \
# shortname
# Human
# Mouse
# Chicken
# Zebrafish
# Yeast
# Cockroach
# Wheat
# Soybean
# Vaccinia
# InfluenzaB
# InfluenzaA                           A/Mexico City/INER13/2009(H1N1))
# CMV
# HCV
# HBV                 genotype C subtype ayr (isolate Human/Japan/Ok...
# HSV1                                                       strain RH2
# DENV
# HIV
# EBV
# Ebola                            Zaire ebolavirus (strain Mayinga-76)
# Ecoli                                        Escherichia coli O157:H7
# Tuberculosis
# Listeria
# Burkholderia
# Meningococcus
# StrepA
# Hpylori                                     causing chronic gastritis
# Lyme
# Tetanus
# Leprosy
# Malaria
# Chagas
# OnchocercaVolvulus                             causes river blindness
#
#                                                       path
# shortname
# Human                            UP000005640Human.fasta.gz
# Mouse                            UP000000589Mouse.fasta.gz
# Chicken                        UP000000539Chicken.fasta.gz
# Zebrafish                    UP000000437Zebrafish.fasta.gz
# Yeast                               UP000002311Yeast.fasta
# Cockroach                    UP000245037Cockroach.fasta.gz
# Wheat                            UP000019116Wheat.fasta.gz
# Soybean                        UP000008827Soybean.fasta.gz
# Vaccinia                         UP000000344Vaccinia.fasta
# InfluenzaB                     UP000127412InfluenzaB.fasta
# InfluenzaA                     UP000116233InfluenzaA.fasta
# CMV                                   UP000008991CMV.fasta
# HCV                                   UP000000518HCV.fasta
# HBV                                   UP000008591HBV.fasta
# HSV1                                 UP000106517HSV1.fasta
# DENV                                 UP000002500DENV.fasta
# HIV                                   UP000002241HIV.fasta
# EBV                                   UP000153037EBV.fasta
# Ebola                               UP000007209Ebola.fasta
# Ecoli                               UP000000558Ecoli.fasta
# Tuberculosis                 UP000001584Tuberculosis.fasta
# Listeria                         UP000000817Listeria.fasta
# Burkholderia                 UP000000605Burkholderia.fasta
# Meningococcus               UP000000425Meningococcus.fasta
# StrepA                             UP000000750StrepA.fasta
# Hpylori                           UP000000429Hpylori.fasta
# Lyme                                 UP000001807Lyme.fasta
# Tetanus                           UP000001412Tetanus.fasta
# Leprosy                           UP000000806Leprosy.fasta
# Malaria                        UP000001450Malaria.fasta.gz
# Chagas                          UP000002296Chagas.fasta.gz
# OnchocercaVolvulus  UP000024404OnchocercaVolvulus.fasta.gz

# %%
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(6,4))

color_map = {
    'P. Falciparum':'#8c564b',
    'Mouse': '#ff7f0e',
    'Chicken': '#2ca02c',
    'Zebrafish': '#d62728',
    'Human Virus Ensemble': '#9467bd',
    'Tuberculosis': '#e377c2',
    'Listeria': '#7f7f7f',
    'StrepA': '#bcbd22',
    'Human': '#1f77b4'
}

label_map = {
    'UP000005640Human.fasta.gz': 'Human',
    'UP000001450Malaria.fasta.gz': 'P. Falciparum',
    'human-viruses-uniref90-filtered.fasta': 'Human Virus Ensemble',
    'UP000000589Mouse.fasta.gz': 'Mouse',
    'UP000000539Chicken.fasta.gz': 'Chicken',
    'UP000000437Zebrafish.fasta.gz': 'Zebrafish',
    'UP000000750StrepA.fasta': 'StrepA',
    'UP000001584Tuberculosis.fasta': 'Tuberculosis',
    'UP000000817Listeria.fasta': 'Listeria'
}

   
      


for fasta, label in label_map.items():
    if label == 'Human':
        continue
    ax[1,0].plot(list(range(len(aminoacids))), freqs[fasta],'-o',label=label, linewidth=.75,color=color_map[label])

ax[0,0].plot(list(range(len(aminoacids))), freqs['UP000005640Human.fasta.gz'],'-o',label='Human', linewidth=.75,color=color_map['Human'])
ax[0,0].set_xticks(list(range(len(aminoacids))))
ax[1,0].set_xticks(list(range(len(aminoacids))))
ax[1,0].set_xticklabels(aminoacids)
ax[0,0].set_xticklabels(aminoacids)
ax[1,0].set_xlabel('Amino Acid')
ax[0,0].set_ylabel('Frequency')
ax[1,0].set_ylabel('Frequency')
ax[0,0].set_ylim([0,.15])
ax[0,0].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
ax[1,0].set_ylim([0,.15])
ax[1,0].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
ax[0,0].legend()

    
    
    
label_map = {
    'bsub_mutualinformation-Human.csv': 'Human',
    'bsub_mutualinformation-Malaria.csv': 'P. Falciparum',
    'bsub_mutualinformation-Viruses.csv': 'Human Virus Ensemble',
    'bsub_mutualinformation-Mouse.csv': 'Mouse',
    'bsub_mutualinformation-Chicken.csv': 'Chicken',
    'bsub_mutualinformation-Zebrafish.csv': 'Zebrafish',
    'bsub_mutualinformation-StrepA.csv': 'StrepA', 
    'bsub_mutualinformation-Tuberculosis.csv': 'Tuberculosis',
    'bsub_mutualinformation-Listeria.csv': 'Listeria'
    
}
     
for path, label in label_map.items():
    df = pd.read_csv(f'{datadir}/{path}')
    if label == 'Human':
        _ax = ax[0,1]
    else:
        _ax = ax[1,1]
    _ax.plot(df['gaps']+1, df['mutualinformation'], 'o',label=label,color=color_map[label],ms=2)


d = np.linspace(1, 200)
#ax.plot(d, 0.005*np.exp(-d/50), zorder=10, label='exponential ($d_c=50$)')
for _ax in [ax[0,1], ax[1,1]]:
    l, = _ax.plot(d, 0.02*d**-.5, zorder=10, c='k', label=r'$d^{-1/2}$')
    _ax.set_ylim(0.00015, 0.05)
    _ax.set_xlim(0.95, 251.0)
    _ax.set_xscale('log')
    _ax.set_yscale('log')
    _ax.set_ylabel('Mutual Information (bits)')

ax[0,1].legend()
ax[1,1].set_xlabel('Distance')

label_axes(fig, labelstyle='%s', xy=(-0.18, 1.07),fontsize=10)

fig.tight_layout()
fig.subplots_adjust(hspace=.55)
plt.savefig('../s1.png')
plt.savefig('../s1.svg')

# %%
fig, ax = plt.subplots()
ax.plot(list(range(len(aminoacids))), freqs['UP000005640Human.fasta.gz'])
ax.set_xticks(list(range(len(aminoacids))))
ax.set_xticklabels(aminoacids)
# Out:
# [Text(0, 0, 'A'),
#  Text(1, 0, 'C'),
#  Text(2, 0, 'D'),
#  Text(3, 0, 'E'),
#  Text(4, 0, 'F'),
#  Text(5, 0, 'G'),
#  Text(6, 0, 'H'),
#  Text(7, 0, 'I'),
#  Text(8, 0, 'K'),
#  Text(9, 0, 'L'),
#  Text(10, 0, 'M'),
#  Text(11, 0, 'N'),
#  Text(12, 0, 'P'),
#  Text(13, 0, 'Q'),
#  Text(14, 0, 'R'),
#  Text(15, 0, 'S'),
#  Text(16, 0, 'T'),
#  Text(17, 0, 'V'),
#  Text(18, 0, 'W'),
#  Text(19, 0, 'Y')]

# %%
freqs['UP000001584Tuberculosis.fasta']
# Out:
# [0.13319433681534318,
#  0.008861370040863573,
#  0.058444205202160156,
#  0.046981866238595696,
#  0.029769589501111433,
#  0.10042207708646333,
#  0.022383090854694344,
#  0.04290226371254603,
#  0.02022255688780503,
#  0.09819194225488162,
#  0.017147464138667495,
#  0.025443562291961604,
#  0.05799462123833619,
#  0.030948186944502375,
#  0.07264885243650482,
#  0.0544843948277494,
#  0.05897407812414896,
#  0.08531791990547963,
#  0.014731955013900079,
#  0.02093566648428504]

# %%
aminoacids
# Out:
# 'ACDEFGHIKLMNPQRSTVWY'

# %%
range(len(aminoacids))
# Out:
# range(0, 20)
